# %%
from bs4 import BeautifulSoup, SoupStrainer
import requests

url = "http://big5.quanben-xiaoshuo.com/n/qingyunian/xiazai.html"

page = requests.get(url)    
data = page.text
soup = BeautifulSoup(data)

domain = []
for link in soup.find_all('a'):
    address = link.get('href')
    domain.append(address)

site = domain[4:-2]

# %%
import pdfkit
import shutil

for i in site:
    title = i[14:-4] + '.pdf'
    pdfkit.from_url('http://big5.quanben-xiaoshuo.com' + i, title)

    old = r'' + title
    new = r'./慶餘年/' + title
    shutil.move(old,new)
# Out:
# Loading pages (1/6)
# Counting pages (2/6)
# Resolving links (4/6)
# Loading headers and footers (5/6)
# Printing pages (6/6)
# Done
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-852babbdeafe> in <module>
#       4 for i in site:
#       5     title = i[14:-4] + '.pdf'
# ----> 6     pdfkit.from_url('http://big5.quanben-xiaoshuo.com' + i, title)
#       7
#       8     old = r'' + title
#
# /usr/local/Cellar/jupyterlab/2.2.8/libexec/lib/python3.8/site-packages/pdfkit/api.py in from_url(url, output_path, options, toc, cover, configuration, cover_first)
#      24                configuration=configuration, cover_first=cover_first)
#      25
# ---> 26     return r.to_pdf(output_path)
#      27
#      28
#
# /usr/local/Cellar/jupyterlab/2.2.8/libexec/lib/python3.8/site-packages/pdfkit/pdfkit.py in to_pdf(self, path)
#     139         else:
#     140             input = None
# --> 141         stdout, stderr = result.communicate(input=input)
#     142         stderr = stderr or stdout
#     143         try:
#
# /usr/local/opt/python@3.8/Frameworks/Python.framework/Versions/3.8/lib/python3.8/subprocess.py in communicate(self, input, timeout)
#    1022
#    1023             try:
# -> 1024                 stdout, stderr = self._communicate(input, endtime, timeout)
#    1025             except KeyboardInterrupt:
#    1026                 # https://bugs.python.org/issue25942
#
# /usr/local/opt/python@3.8/Frameworks/Python.framework/Versions/3.8/lib/python3.8/subprocess.py in _communicate(self, input, endtime, orig_timeout)
#    1864                             'failed to raise TimeoutExpired.')
#    1865
# -> 1866                     ready = selector.select(timeout)
#    1867                     self._check_timeout(endtime, orig_timeout, stdout, stderr)
#    1868
#
# /usr/local/opt/python@3.8/Frameworks/Python.framework/Versions/3.8/lib/python3.8/selectors.py in select(self, timeout)
#     413         ready = []
#     414         try:
# --> 415             fd_event_list = self._selector.poll(timeout)
#     416         except InterruptedError:
#     417             return ready
#
# KeyboardInterrupt:

# %%
from io import StringIO

from pdfminer.converter import TextConverter
from pdfminer.layout import LAParams
from pdfminer.pdfdocument import PDFDocument
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.pdfpage import PDFPage
from pdfminer.pdfparser import PDFParser

output_string = StringIO()

with open(new, 'rb') as in_file:
    parser = PDFParser(in_file)
    doc = PDFDocument(parser)
    rsrcmgr = PDFResourceManager()
    device = TextConverter(rsrcmgr, output_string, laparams=LAParams())
    interpreter = PDFPageInterpreter(rsrcmgr, device)
    for page in PDFPage.create_pages(doc):
        interpreter.process_page(page)
print(output_string.getvalue())
# Out:
# ./慶餘年/1.pdf
# ⾸⾴
#
# 當前位置：⾸⾴	›曆史⼩說	›	《慶餘年》›	⽬錄
#
# 搜索
#
# 楔⼦	⼀塊⿊布
# 楔⼦	⼀塊⿊布
# 楔⼦	⼀塊⿊布
#
# 書名：《慶餘年》 作者：貓膩 字體：＋⼤中⼩－
#
# 楔⼦	⼀塊⿊布
# 範慎很困難地撐著上眼⽪，看著指頭算⾃⼰這輩⼦做過些什麽有意義的事情，結果右⼿五根瘦成筷⼦⼀樣的指頭
#
# 還沒有數完，他就歎了⼀⼝氣，很傷⼼地放棄了這個⼯作。
#
# 病房裏的藥⽔味總是這麽刺⿐，旁邊那床的老爺⼦前兩天已經去地藏王菩薩那裏報道了，⼤概再過幾天就輪到⾃
#
# 他得了某種怪病，重症肌無⼒，就是特別適合男主⾓的那種病。據說沒得醫，將來嗝屁的那天什麽都動不了，隻
#
# “可我不是⾔情啊。”範慎咕噥著，但由於兩頜的肌⾁沒有了作⽤，所以變成⼀串含糊的囈語。
#
# 他望著⾃⼰的中指頭，很同情⾃⼰，“我還是處男。”
#
# ⼰吧。
#
# 有眼淚可以流下來。
#
# …
# 騎兵分出⼀隊，就像⿊夜裏的鐮⼑⼀樣，毫不留情地衝進了死傷慘重的殺⼿隊伍。
#
# 忽然間，殺⼿隊伍裏的⼀位法師舉起了法杖，開始吟念起咒語，場中的⼈都能感覺到有些不知名的能量波動開始
#
# 在這⽚丘陵邊上匯集。
#
# 的⾎。
#
# …
#
# 皇太後及元老會執政。
#
# 案。
#
# 道⼝上，。
#
# ⾺⾞上的中年⼈微微皺眉，也沒有什麽動作，他⾝邊卻躥出了⼀個⿊影，像鷹隼⼀樣在夜空裏疾速飄了過去。
#
# ⼀聲脆響，法師的吟誦嘎然⽽⽌，頭顱⾼⾼地⾶了起來，鮮⾎如雨。
#
# 坐⾺⾞上的中年⼈搖搖頭：“從⻄邊來的這些法師總是不明⽩，在真正的強者麵前，法術就和丞相⼤⼈的筆⼀樣，
#
# 是不起作⽤的。”
#
# 幾⼗名肅殺⼗⾜的⿊⾊騎兵確認了四周的安全，握緊右拳比了⼀個⼿勢，報告四周的殺⼿已經清除完畢。
#
# 騎兵隊伍分開，裏麵的⾺⾞緩緩前⾏，來到了少年仆⼈的⾝前。⾺⾞上的中年⼈在下屬的幫助下坐上輪椅，雙腿
#
# 不良於⾏的中年⼈推著⾝下的輪椅，緩緩地靠近了場中央，⼀直筆直如槍的那個少年。
#
# 看著少年仆⼈背後的⽵簍，坐著輪椅的中年⼈蒼⽩的臉上終於現出⼀絲紅暈：“總算沒有出事。”
#
# 背著⽵簍的那⼈臉上蒙著⼀條⿊⾊布帶，⼿上提著⼀把似劍非劍的⿊⾊鐵釺，還有鮮⾎從鐵釺上緩緩滴下，在他
#
# 的⾝側倒伏著許多死屍，死屍都是伏擊的⾼⼿，屍體的咽喉上殘留著⾎點，看來是⼀擊致命。
#
# “這件事情我需要你們給我⼀個交待。”眼睛上蒙著⿊⾊布帶的⼈冷冷說道，他說話的語⾳沒有⼀絲顫抖，也沒有
#
# ⼀絲感情。
#
# 坐在輪椅上的中年⼈麵上的柔惜之⾊⼀現即隱：“我⾃然會給你⼀個交待，我也必須要給主⼈⼀個交待。”
#
# 蒙著⿊⾊布帶的少年仆⼈點點頭，然後準備離開。
#
# “你要把這孩⼦帶到哪裏去？”坐在輪椅上的中年⼈冷冷說道：“你是個瞎⼦，難道讓少爺跟著你浪跡江湖。”
#
# “這是⼩姐的⾎⾁。”
#
# 那⼈搖搖頭，扯了扯⾃⼰臉上的⿊布條。
#
# “這也是主⼦的⾎⾁！”輪椅上的中年⼈陰冷說著，“我保證在京都裏給⼩主⼦找⼀個很安全的地⽅。”
#
# 輪椅上的中年⼈知道對⽅除了聽那位⼩姐的話，就算是⾃⼰的主⼈也不可能命令他，隻好歎⼝氣勸解道：“京都裏
#
# 的事情，等主⼦回來了，就⼀定能平息，你何必⼀定要帶他走。”
#
# “我不信任你的主⼦。”
#
# 笑道：“瞎⼦，你除了殺⼈還會什麽？”
#
#
# 曆史關頭，以他個⼈的勇猛和戰⼒，刺殺了野蠻⼈原始議會裏的⼤部分成員。
#
# 也有的天脈者會表現出在藝術或者智慧上的極⼤天賦，比如⻄⽅的那個剛死了三百年的波爾**師及他的夫⼈劇作
#
# ⾃然，沒有⼈能證明他們是上天眷顧苦難的⼈間，⽽留下來的⾎脈。但事實上，這幾個⼈給⼈間帶來了和平與很
#
# 家伏波。
#
# 多其它的東⻄。
#
# ⽽且所有的天脈者最後都消失的無影無蹤，沒有任何⼀個⼈、甚⾄是國家可以察到蛛絲⾺跡。他們隻是突然的出
#
# 現，⼜突然的消失，除了留下⼀些隱晦的記載之後，根本沒有留下任何可以證明他們存在的東⻄。
#
# 坐在輪椅上的中年⼈，恰恰是知道天脈者這種異象確實存在的極少數⼈之⼀。
#
# 不知什麽原因，範慎死去之後，靈魂來到這個世界，就是這樣…不可思議地投⽣到⼀個嬰兒的⾝體裏，⽽且這個
#
# 嬰兒的⽗親或者是⺟親，居然是⼤陸上麵神秘莫測的天脈者。
#
# 天明時，戰場已經被打掃幹淨，⾺⾞緩緩走上了通往東麵的⽯板路，在⾺⾞之後，⼀隊⿊⾊騎兵與⼀位坐在輪騎
#
# 上的蒼⽩中年構成了⼀幅很詭魅的畫麵。
#
# ⾺⾞硌著⽯頭，巔波了⼀下，將平躺在軟⾊絲綢墊上的嬰孩弄醒了。
#
# 嬰兒的雙眼有些無神地離開那些救了⾃⼰性命的⼈們麵容，望著⾺⾞的前⽅，全不像⼀般的嬰孩那樣視線遊移，
#
# 清澈無比卻無法聚焦，卻多了幾絲說不清道不明的味道。
#
# 沒有⼈知道，這樣⼀個柔嫩的⼩⾝體裏，竟然容納著⼀個來⾃不同世界的靈魂。
#
# ⽬光及處，那處的⾞簾隨著迎麵⽽來的風飄了起來，露出⼀⾓⾞外的⻘⻘⼭⾊，和疾退⽽後的長長⽯板路，就像
#
# 是無數幅的畫麵，正在不停地倒帶。
#
# ⾺⾞前⽅，瞎⼦少年正緊緊握著⼿中的鐵釺，眼睛上麵蒙著⼀塊⿊布，蒙住了他的雙眼，也蒙住了這天。
#
# 回 ⽬ 錄
#
# 下 ⼀ 章
#
# CopyRight	©	2010-2019,	quanben-xiaoshuo.com	All	Rights	Reserved,	Powered	By	全本⼩說網

# %%
from gtts import gTTS

myAudio = gTTS(text=output_string.getvalue(), lang='zh-yu', slow=False)

myAudio.save("Audio.mp3")

# %%
def chinese_to_pinyin(x):

y = ''

dic = {}

with open("unicode_pinyin.txt") as f:

for i in f.readlines():

dic[i.split()[0]] = i.split()[1]

for i in x:

i = str(i.encode('unicode_escape'))[-5:-1].upper()

try:

y += dic[i] + ' '

except:

y += 'XXXX ' #非法字符我們用XXXX代替

return y
# Out:
#   File "<ipython-input-45-cc046d9d14b7>", line 3
#     y = ''
#     ^
# IndentationError: expected an indented block
